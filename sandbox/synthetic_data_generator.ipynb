# %%
# %%sql

# %% [markdown]
# # Synthetic Data Generator
#
# [Open In Collab]('colab.research.google.com/github/bdJohnson72/ai-engineering/blob/main/sandbox/synthetic_data_generator.ipynb')

# %%
from unittest import result
# !pip install -q --upgrade bitsandbytes accelerate transformers==4.57.6
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 80.2 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 45.8 MB/s eta 0:00:00

# %%
# imports
import os
import requests
from IPython.display import  Markdown, display, update_display
from openai import OpenAI
from google.colab import drive
from huggingface_hub import login
from google.colab import userdata
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer, BitsAndBytesConfig
import torch

# %%
LLAMA = 'meta-llama/llama-3.2-3b-Instruct'

# %%
hf_token = os.getenv('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
from transformers import pipeline
generator = pipeline("text-generation", model=LLAMA, device="cuda")
result = generator('generate a csv that can be used to train a machine learning model to predict housing data prices. It should have 10 columns and 20 rows')
# Out:
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# Device set to use cuda
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %%
result
# Out:
# [{'generated_text': 'generate a csv that can be used to train a machine learning model to predict housing data prices. It should have 10 columns and 20 rows. We\'ll use the following features to train our model:\n*   **feature1:** The number of bedrooms\n*   **feature2:** The number of bathrooms\n*   **feature3:** The number of floors\n*   **feature4:** The square footage\n*   **feature5:** The year built\n*   **feature6:** The number of rooms\n*   **feature7:** The number of parking spaces\n*   **feature8:** The lot size\n*   **feature9:** The location (city or neighborhood)\n*   **feature10:** The type of housing (single-family home, townhouse, apartment, etc.)\n\nHere\'s a sample CSV file that we can use:\n\n```\n"feature1","feature2","feature3","feature4","feature5","feature6","feature7","feature8","feature9","feature10"\n"3","2","1","1500","2000","5","2","0","0.25","Suburban"\n"4","3","2","2500","3000","7","3","1","0.5","City Center"\n"2","1","1","1200","1500","4","1","0","0.2",
# ...
